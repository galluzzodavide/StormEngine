# %%
import xarray as xr
ds = xr.open_dataset('nc_files/129250-99999.nc')
print(ds['slp'].values[:5])  # mostra i primi 5 valori grezzi
print(ds['slp'].attrs)       # mostra unità e scale factor
ds.close()
# Out:
# [1039.9 1039.3 1038.3 1039.1 1037. ]
# {'long_name': 'Reported Sea Level Pressure at screen height (~2m)', 'units': 'hPa', 'flagged_value': np.float64(-2e+30), 'valid_min': np.float64(968.6), 'valid_max': np.float64(1048.6), 'standard_name': 'air_pressure_at_sea_level', 'cell_methods': 'latitude: longitude: time: point (nearest to reporting hour)'}

# %%
import xarray as xr
ds = xr.open_dataset('nc_files/129250-99999.nc')
print('slp:', ds['slp'].values[:3], ds['slp'].attrs.get('units'))
print('temperatures:', ds['temperatures'].values[:3], ds['temperatures'].attrs.get('units'))
print('windspeeds:', ds['windspeeds'].values[:3], ds['windspeeds'].attrs.get('units'))
print('winddirs:', ds['winddirs'].values[:3], ds['winddirs'].attrs.get('units'))
ds.close()
# Out:
# slp: [1039.9 1039.3 1038.3] hPa
# temperatures: [-8. -4. -7.] degree_Celsius
# windspeeds: [1. 1. 3.] meters per second
# winddirs: [360. 360. 360.] degree
